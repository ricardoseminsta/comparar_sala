# %% [markdown]
# ## Comparando Bens nas salas
# #### comparando os bens de uma planilha de levantamento físico com o estado real do SUAP

# %%
# importando o pandas e a planilha dap pra realizar testes
import pandas as pd

tombos_df = pd.read_excel('dap.xlsx')
# display(tombos_df.head())

suap_df = pd.read_excel('dap_suap.xlsx')
# display(suap_df.head())

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
import time

nav = webdriver.Chrome()
nav.get('https://suap.ifpe.edu.br/accounts/login/?next=/')

# inserindo usuário
nav.find_element_by_xpath('//*[@id="id_username"]').click()
nav.find_element_by_xpath('//*[@id="id_username"]').send_keys("2184579")

# inserindo senha 
nav.find_element_by_xpath('//*[@id="id_password"]').click()
nav.find_element_by_xpath('//*[@id="id_password"]').send_keys("sis1986%")

nav.find_element_by_xpath('//*[@id="ok"]').click()

# informações relevantes da comparação
tombo_lista = []
carga_lista = []
descricao_lista = []


linha = ['83317', '85223', '85272']
# buscando tombo do bem

for tombo in tombos_df['tombo']:
    nav.get(f"https://suap.ifpe.edu.br/patrimonio/inventario/{tombo}/")
    
    tombo_lista.append(tombo)
    print(tombo)
    
    descricao = nav.find_element_by_xpath("/html/body/div[1]/div[3]/table[1]/tbody/tr[6]/td[2]/span[1]").get_attribute('innerText')
    descricao_lista.append(descricao)
    print(descricao)
    
    carga = nav.find_element_by_xpath("/html/body/div[1]/div[3]/table[1]/tbody/tr[7]/td[2]").get_attribute('innerText')
    carga_lista.append(carga)
    print(carga)

    
# time.sleep(15)
# nav.quit()

# %%
# diferanca = pd.merge(tombos_df.tombo, suap_df.tombo)

levantamento_fisico = pd.DataFrame()
levantamento_fisico['tombo'] = tombo_lista
levantamento_fisico['DESCRICAO'] = descricao_lista
levantamento_fisico['CARGA ATUAL'] = carga_lista

# display(levantamento_fisico)

diferanca = pd.merge(levantamento_fisico, suap_df, on='tombo', how='outer', indicator=True, suffixes=('_lev_fisico','_suap'))
display(diferanca)
# diferanca.to_excel('diferenca.xlsx')
# Out:
#      tombo                               DESCRICAO_lev_fisico  \
# 0    83317  APARELHO DE AR CONDICIONADO, CAPACIDADE DE REF...
# 1    85223      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 2    85272      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 3    85308      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 4    85216      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 5    85219      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 6    85289      ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 7   174708  MESA APOIO PARA OS PÉS. ESPECIFICAÇÕES: CONSTR...
# 8   174703  MESA APOIO PARA OS PÉS. ESPECIFICAÇÕES: CONSTR...
# 9   174709  MESA APOIO PARA OS PÉS. ESPECIFICAÇÕES: CONSTR...
# 10  174704  MESA APOIO PARA OS PÉS. ESPECIFICAÇÕES: CONSTR...
# 11  174721  MESA APOIO PARA OS PÉS. ESPECIFICAÇÕES: CONSTR...
# 12   38148  Poltrona operacional, espaldar baixo, giratóri...
# 13   38206  Poltrona operacional, espaldar baixo, giratóri...
# 14   38141  Poltrona operacional, espaldar baixo, giratóri...
# 15   38140  Poltrona operacional, espaldar baixo, giratóri...
# 16   38150  Poltrona operacional, espaldar baixo, giratóri...
# 17   38212  Poltrona operacional, espaldar baixo, giratóri...
# 18   38149  Poltrona operacional, espaldar baixo, giratóri...
# 19  164329  POLTRONA GIRATÓRIA ESPALDAR BRAÇOS( TIPO PRESI...
# 20   38151  Poltrona operacional, espaldar baixo, giratóri...
# 21  167066     ARMÁRIO ALTO FECHADO DIMENSÕES: 800X640X2100MM
# 22   37636  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 23   37637  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 24   37640  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 25   37359  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 26   37357  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 27   37358  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 28   37851  MESA DE ADVOGADO, especificação conf. edital. ...
# 29   37715  MÓDULO COMPLEMENTAR: Especificação conf.edital...
# 30   37826                      Estação de trabalho,MESA EM L
# 31   37818  Estação de trabalho, especificação conforme ed...
# 32   37832  Estação de trabalho, especificação conforme ed...
# 33   37467  Gaveteiro volante três gavetas conf. especific...
# 34   37460  Gaveteiro volante três gavetas conf. especific...
# 35   37454  Gaveteiro volante três gavetas conf. especific...
# 36   77187          IMPRESSORA LASER MONOCROMÁTICA HP P2055DN
# 37   83397  BEBEDOURO DE AGUA, TIPO COLUNA, COM COMPRESSOR...
# 38   98631  COMPUTADOR DESKTOP ALL IN ONE, PROCESSADOS COR...
# 39  125776  MICROCOMPUTADOR - ESTAÇÃO DE TRABALHO TUDO EM ...
# 40  125774  MICROCOMPUTADOR - ESTAÇÃO DE TRABALHO TUDO EM ...
# 41   74170                                    PONTO DE ACESSO
# 42   37462                                                NaN
# 43   37833                                                NaN
# 44   38334                                                NaN
# 45   38337                                                NaN
# 46   73121                                                NaN
# 47   83318                                                NaN
# 48   83361                                                NaN
# 49   83370                                                NaN
# 50   85982                                                NaN
# 51   92700                                                NaN
# 52   98629                                                NaN
# 53  125781                                                NaN
# 54  164245                                                NaN
# 55  164248                                                NaN
#
#                               CARGA ATUAL_lev_fisico  \
# 0                José Leandro Cândido (CAFI AFI-CAD)
# 1         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 2         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 3         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 4         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 5         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 6         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 7         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 8         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 9         Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 10        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 11        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 12        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 13   MARCOS SIMPLÍCIO PEREIRA JÚNIOR (CAFI AFI-CCLC)
# 14   WILLIBALDO JOSE DA COSTA JUNIOR (CAFI AFI-CCLC)
# 15   WILLIBALDO JOSE DA COSTA JUNIOR (CAFI AFI-CCLC)
# 16        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 17   WILLIBALDO JOSE DA COSTA JUNIOR (CAFI AFI-CCLC)
# 18        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 19        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 20        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 21        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 22        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 23        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 24        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 25        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 26        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 27        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 28        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 29  Carlos Eduardo Cabral Rodrigues (CAFI AFI-CCBEC)
# 30        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 31        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 32        Ana Claudia Costa Carvalho (CIPJ IPJ-CCON)
# 33          José Hugo Vitorino Silva (CAFI AFI-CGTI)
# 34        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 35     Breno Eliésio de Souza e Silva (CAFI AFI-DAP)
# 36  Carlos Eduardo Cabral Rodrigues (CAFI AFI-CCBEC)
# 37        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 38        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 39        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 40     Breno Eliésio de Souza e Silva (CAFI AFI-DAP)
# 41        Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)
# 42                                               NaN
# 43                                               NaN
# 44                                               NaN
# 45                                               NaN
# 46                                               NaN
# 47                                               NaN
# 48                                               NaN
# 49                                               NaN
# 50                                               NaN
# 51                                               NaN
# 52                                               NaN
# 53                                               NaN
# 54                                               NaN
# 55                                               NaN
#
#                                        DESCRICAO_suap  \
# 0                                                 NaN
# 1       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 2       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 3       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 4       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 5       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 6       ESTABILIZADOR 1 KVA BIVOLT AUTOMATICO: 1000VA
# 7   MESA APOIO  PARA OS PÉS. ESPECIFICAÇÕES: CONST...
# 8   MESA APOIO  PARA OS PÉS. ESPECIFICAÇÕES: CONST...
# 9   MESA APOIO  PARA OS PÉS. ESPECIFICAÇÕES: CONST...
# 10  MESA APOIO  PARA OS PÉS. ESPECIFICAÇÕES: CONST...
# 11  MESA APOIO  PARA OS PÉS. ESPECIFICAÇÕES: CONST...
# 12  Poltrona operacional, espaldar baixo, giratóri...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  Poltrona operacional, espaldar baixo, giratóri...
# 17                                                NaN
# 18  Poltrona operacional, espaldar baixo, giratóri...
# 19  POLTRONA GIRATÓRIA ESPALDAR BRAÇOS( TIPO PRESI...
# 20  Poltrona operacional, espaldar baixo, giratóri...
# 21     ARMÁRIO ALTO FECHADO DIMENSÕES: 800X640X2100MM
# 22  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 23  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 24  ESTANTE EM MADEIRA SEMIABERTA conf. especifica...
# 25  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 26  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 27  ARMÁRIO BAIXO FECHADO conf.especificado no edi...
# 28  MESA DE ADVOGADO, especificação conf. edital.\...
# 29                                                NaN
# 30                      Estação de trabalho,MESA EM L
# 31  Estação de trabalho, especificação conforme ed...
# 32                                                NaN
# 33                                                NaN
# 34  Gaveteiro volante três gavetas conf. especific...
# 35  Gaveteiro volante três gavetas conf. especific...
# 36                                                NaN
# 37  BEBEDOURO DE AGUA, TIPO COLUNA, COM COMPRESSOR...
# 38  COMPUTADOR DESKTOP ALL IN ONE, PROCESSADOS COR...
# 39  MICROCOMPUTADOR - ESTAÇÃO DE TRABALHO TUDO EM ...
# 40  MICROCOMPUTADOR - ESTAÇÃO DE TRABALHO TUDO EM ...
# 41                                    PONTO DE ACESSO
# 42  Gaveteiro volante três gavetas conf. especific...
# 43  Estação de trabalho, especificação conforme ed...
# 44        POLTRONA OPERACIONAL, ESPALDAR BAIXO, FIXA.
# 45        POLTRONA OPERACIONAL ESPALDA   BAIXO, FIXA.
# 46  IMPRESSORA MULTIFUNCIONAL SAMSUNG SCX-4828FN L...
# 47  APARELHO DE AR CONDICIONADO, CAPACIDADE DE REF...
# 48                       APARELHO TELEFONICO COM FIO.
# 49  APARELHO TELEFONICO COM FIO E SISTEMA DUPLO DE...
# 50  CALCULADORA ELETRÔNICA, NÚMERO DÍGITOS 14UN, T...
# 51                      TELEVISÃO LCD 32 POL. SAMSUNG
# 52  COMPUTADOR DESKTOP ALL IN ONE, PROCESSADOS COR...
# 53  MICROCOMPUTADOR - ESTAÇÃO DE TRABALHO TUDO EM ...
# 54  POLTRONA FIXA  COM ENCOSTO OU ESPALDAR MÉDIO  ...
# 55  POLTRONA FIXA  COM ENCOSTO OU ESPALDAR MÉDIO  ...
#
#                                  CARGA ATUAL_suap      _merge
# 0                                             NaN   left_only
# 1      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 2      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 3      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 4      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 5      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 6      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 7      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 8      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 9      Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 10     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 11     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 12     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 13                                            NaN   left_only
# 14                                            NaN   left_only
# 15                                            NaN   left_only
# 16     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 17                                            NaN   left_only
# 18     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 19     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 20     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 21     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 22     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 23     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 24     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 25     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 26     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 27     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 28     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 29                                            NaN   left_only
# 30     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 31     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 32                                            NaN   left_only
# 33                                            NaN   left_only
# 34     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 35  Breno Eliésio de Souza e Silva (CAFI AFI-DAP)        both
# 36                                            NaN   left_only
# 37     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 38     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 39     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 40  Breno Eliésio de Souza e Silva (CAFI AFI-DAP)        both
# 41     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)        both
# 42     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 43     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 44     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 45     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 46     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 47     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 48     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 49     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 50     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 51     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 52     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 53     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 54     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only
# 55     Ezenildo Emanuel de Lima (CAFI AFI-CODAGR)  right_only

# %%
# bni bem nao inventariado
